# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>City Hospital - Healthcare at its Finest</title>
    <link rel="stylesheet" href="style.css">
</head>
<body>
    <nav class="navbar">
        <div class="logo">City Hospital</div>
        <ul class="nav-links">
            <li><a href="#home">Home</a></li>
            <li><a href="#doctors">Doctors</a></li>
            <li><a href="#staff">Staff</a></li>
            <li><a href="#patients">Patients</a></li>
            <li><a href="#rooms">Rooms</a></li>
            <li><a href="#services">Services</a></li>
            <li><a href="#appointment" class="appointment-btn">Book Appointment</a></li>
        </ul>
    </nav>

    <section id="home" class="hero">
        <h1>Welcome to City Hospital</h1>
        <p>Providing Quality Healthcare Services Since 1990</p>
    </section>

    <section id="doctors" class="section">
        <h2>Our Doctors</h2>
        <div class="card-container">
            <div class="card">
                <img src="https://placehold.co/200x200" alt="Doctor">
                <h3>Dr. Sarah Johnson</h3>
                <p>Cardiologist</p>
                <p>Available: Mon-Fri</p>
            </div>
            <div class="card">
                <img src="https://placehold.co/200x200" alt="Doctor">
                <h3>Dr. Michael Chen</h3>
                <p>Neurologist</p>
                <p>Available: Wed-Sun</p>
            </div>
            <div class="card">
                <img src="https://placehold.co/200x200" alt="Doctor">
                <h3>Dr. Emily Brown</h3>
                <p>Pediatrician</p>
                <p>Available: Mon-Sat</p>
            </div>
        </div>
    </section>

    <section id="staff" class="section">
        <h2>Hospital Staff</h2>
        <div class="card-container">
            <div class="card">
                <img src="https://placehold.co/200x200" alt="Staff">
                <h3>Nursing Department</h3>
                <p>24/7 Care Available</p>
                <p>Staff: 50+</p>
            </div>
            <div class="card">
                <img src="https://placehold.co/200x200" alt="Staff">
                <h3>Emergency Response</h3>
                <p>Quick Response Team</p>
                <p>Staff: 25+</p>
            </div>
        </div>
    </section>

    <section id="patients" class="section">
        <h2>Patient Information</h2>
        <div class="patient-info-container">
            <div class="info-card">
                <h3>Admission Process</h3>
                <ul class="info-list">
                    <li>Valid ID and Insurance Information</li>
                    <li>Medical History Documentation</li>
                    <li>Emergency Contact Details</li>
                    <li>Current Medication List</li>
                </ul>
            </div>
            <div class="info-card">
                <h3>Patient Rights</h3>
                <ul class="info-list">
                    <li>Access to Medical Records</li>
                    <li>Privacy Protection</li>
                    <li>Treatment Information</li>
                    <li>Grievance Resolution</li>
                </ul>
            </div>
            <div class="info-card">
                <h3>Visiting Hours</h3>
                <ul class="info-list">
                    <li>General Ward: 10 AM - 8 PM</li>
                    <li>ICU: 11 AM - 6 PM</li>
                    <li>Pediatric: 9 AM - 7 PM</li>
                    <li>Weekend Hours: 11 AM - 5 PM</li>
                </ul>
            </div>
        </div>
    </section>

    <section id="rooms" class="section">
        <h2>Room Availability</h2>
        <div class="room-status">
            <div class="room-type">
                <h3>General Ward</h3>
                <p class="available">Available Beds: 15</p>
            </div>
            <div class="room-type">
                <h3>Private Rooms</h3>
                <p class="limited">Available Rooms: 5</p>
            </div>
            <div class="room-type">
                <h3>ICU</h3>
                <p class="full">Available Beds: 2</p>
            </div>
        </div>
    </section>

    <section id="services" class="section">
        <h2>Our Services</h2>
        <div class="services-grid">
            <div class="service-item">
                <h3>Emergency Care</h3>
                <p>24/7 emergency medical services</p>
            </div>
            <div class="service-item">
                <h3>Laboratory</h3>
                <p>Advanced diagnostic testing</p>
            </div>
            <div class="service-item">
                <h3>Pharmacy</h3>
                <p>In-house pharmacy services</p>
            </div>
            <div class="service-item">
                <h3>Rehabilitation</h3>
                <p>Physical therapy and rehabilitation</p>
            </div>
        </div>
    </section>

    <section id="appointment" class="section">
        <h2>Book an Appointment</h2>
        <form id="appointment-form" class="appointment-form">
            <div class="form-group">
                <label for="name">Full Name:</label>
                <input type="text" id="name" name="name" required>
            </div>
            <div class="form-group">
                <label for="email">Email:</label>
                <input type="email" id="email" name="email" required>
            </div>
            <div class="form-group">
                <label for="phone">Phone:</label>
                <input type="tel" id="phone" name="phone" required>
            </div>
            <div class="form-group">
                <label for="department">Department:</label>
                <select id="department" name="department" required>
                    <option value="">Select Department</option>
                    <option value="cardiology">Cardiology</option>
                    <option value="neurology">Neurology</option>
                    <option value="pediatrics">Pediatrics</option>
                    <option value="orthopedics">Orthopedics</option>
                </select>
            </div>
            <div class="form-group">
                <label for="date">Preferred Date:</label>
                <input type="date" id="date" name="date" required>
            </div>
            <button type="submit" class="submit-btn">Book Appointment</button>
        </form>
    </section>

    <footer class="footer">
        <div class="footer-content">
            <div class="footer-section">
                <h3>Contact Us</h3>
                <p>Email: info@cityhospital.com</p>
                <p>Phone: (555) 123-4567</p>
                <p>Address: 123 Healthcare Ave, Medical City</p>
            </div>
            <div class="footer-section">
                <h3>Emergency</h3>
                <p class="emergency-contact">Emergency: 911</p>
                <p>Ambulance: (555) 999-9999</p>
            </div>
        </div>
        <div class="footer-bottom">
            <p>&copy; 2024 City Hospital. All rights reserved.</p>
        </div>
    </footer>

    <script src="main.js"></script>
</body>
</html>

# %%
// Simple form handling
document.getElementById('appointment-form').addEventListener('submit', function(e) {
    e.preventDefault();
    
    // Get form values
    const name = document.getElementById('name').value;
    const email = document.getElementById('email').value;
    const phone = document.getElementById('phone').value;
    const department = document.getElementById('department').value;
    const date = document.getElementById('date').value;

    // Simple validation
    if (name && email && phone && department && date) {
        alert('Thank you for booking an appointment! We will contact you shortly.');
        this.reset();
    } else {
        alert('Please fill in all fields');
    }
});

// Smooth scrolling for navigation links
document.querySelectorAll('a[href^="#"]').forEach(anchor => {
    anchor.addEventListener('click', function (e) {
        e.preventDefault();
        document.querySelector(this.getAttribute('href')).scrollIntoView({
            behavior: 'smooth'
        });
    });
});s
